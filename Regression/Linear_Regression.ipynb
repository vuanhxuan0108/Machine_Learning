# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from Model.LinearRegression import LinearRegression

# %%
data = pd.read_csv(r"Cellphone.csv")
data.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
dtTrain, dtTest = train_test_split(data, test_size=0.3, shuffle=False)
X_Train = dtTrain.iloc[:, 2:]
y_Train = dtTrain.iloc[:, 1]
X_Test = dtTest.iloc[:, 2:]
y_Test = dtTest.iloc[:, 1]

# %%
model = LinearRegression()
model.fit(X_Train.values, y_Train.values)
print("Các nghiệm của bài toán là: ")
print("=> Weight: ", model.w)
print("=> bias: ", model.bias)
# Out:
# Các nghiệm của bài toán là:
# => Weight:  [-8.04664034e-02  1.02064106e+00 -1.02585905e+02  1.23160866e+00
#   5.33949185e+01  7.73332862e+01  7.08879412e+00  1.00411155e+02
#   1.66115553e+01 -6.40980207e+00  5.81574899e-02 -8.95090952e+01]
# => bias:  1895.3694205631527

# %%
print("Giá trị thực tế\t Giá trị dự đoán\t Độ lệch")
y_pred = np.array(model.predict(X_Test))
for i in range (0, len(y_pred)):
    print(y_Test.values[i],"\t\t",y_pred[i], "\t", y_Test.values[i] - y_pred[i])
# Out:
# Giá trị thực tế	 Giá trị dự đoán	 Độ lệch
# 2975 		 2957.5810595506314 	 17.41894044936862
# 754 		 849.5172682360871 	 -95.51726823608715
# 2880 		 3085.9033581369467 	 -205.90335813694674
# 2858 		 2821.8087724741254 	 36.19122752587464
# 3287 		 2871.88843550747 	 415.11156449252985
# 3287 		 2870.0377082296286 	 416.9622917703714
# 2054 		 2368.018109974913 	 -314.01810997491293
# 1734 		 1458.1360670449599 	 275.8639329550401
# 1734 		 1457.8142014314221 	 276.18579856857787
# 2054 		 2367.0525131342997 	 -313.0525131342997
# 2001 		 1827.4303506892604 	 173.56964931073958
# 2001 		 1826.9475522689538 	 174.0524477310462
# 2880 		 3077.1325201680443 	 -197.13252016804427
# 705 		 598.9030560361209 	 106.09694396387908
# 705 		 598.5811904225832 	 106.41880957741682
# 2491 		 2715.4229446830623 	 -224.42294468306227
# 2491 		 2715.342478279678 	 -224.34247827967783
# 2466 		 2618.7357225781525 	 -152.7357225781525
# 1357 		 1292.3040471241982 	 64.69595287580182
# 1357 		 1289.0049245854366 	 67.99507541456342
# 2466 		 2613.2640071480114 	 -147.2640071480114
# 2266 		 2131.398681903771 	 134.60131809622908
# 2266 		 2130.11121944962 	 135.88878055038003
# 2445 		 2296.5767608812534 	 148.42323911874655
# 2445 		 2291.587843871419 	 153.41215612858105
# 3116 		 2945.6032451438623 	 170.3967548561377
# 2409 		 2171.022431826493 	 237.97756817350682
# 2409 		 2168.286574111423 	 240.71342588857715
# 628 		 269.4531615750732 	 358.5468384249268
# 628 		 265.4298414058517 	 362.5701585941483
# 2508 		 2594.34514945378 	 -86.34514945377987
# 2508 		 2589.999963671021 	 -81.99996367102085
# 1921 		 1615.7338913719766 	 305.2661086280234
# 1921 		 1609.2161126978378 	 311.78388730216216
# 3102 		 3282.1455040003157 	 -180.14550400031567
# 3102 		 3280.7775751427807 	 -178.77757514278073
# 3055 		 2958.1620366307416 	 96.83796336925843
# 614 		 592.9898467579346 	 21.01015324206537
# 614 		 592.0242499173214 	 21.975750082678587
# 3055 		 2952.7707876039844 	 102.22921239601555
# 4361 		 3907.053128540107 	 453.9468714598929
# 4361 		 3903.593073194577 	 457.40692680542315
# 2536 		 2264.3698310701175 	 271.63016892988253
# 3551 		 3275.434200465881 	 275.5657995341189
# 3551 		 3256.926927687462 	 294.073072312538
# 3211 		 3165.0280595909053 	 45.971940409094714
# 3260 		 2491.7553409473744 	 768.2446590526256
# 3211 		 3090.1943044433856 	 120.80569555661441
# 2536 		 1766.443726927266 	 769.556273072734

# %%
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error
y_mean = np.mean(y_Test)
# Tính NSE
nse = 1 - (np.sum((y_Test - y_pred) ** 2) / np.sum((y_Test - y_mean) ** 2))

#Tinh R2
r2 = r2_score(y_Test, y_pred)

# Tính MAE
mae = mean_absolute_error(y_Test, y_pred)

# Tính RMSE
rmse = np.sqrt(mean_squared_error(y_Test, y_pred))

# In giá trị 
print("NSE:", nse)
print("R2: ", r2)
print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# NSE: 0.9143055994489925
# R2:  0.9143055994489925
# MAE: 220.22560145360535
# RMSE: 272.95830996540644
