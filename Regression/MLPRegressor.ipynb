# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor

# %%
data = pd.read_csv(r"Cellphone.csv")
data.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
dtTrain, dtTest = train_test_split(data, test_size = 0.3, shuffle = True)  
X_Train = dtTrain.iloc[:,2:]
y_Train = dtTrain.iloc[:,1]
X_Test = dtTest.iloc[:,2:]
y_Test = dtTest.iloc[:,1]

# %%
model = MLPRegressor(hidden_layer_sizes=(170, 200,) ,max_iter=5000, activation="identity", alpha=0.001)
model.fit(X_Train, y_Train)
y_pred = model.predict(X_Test)

# %%
print("Thuc te           Du doan                Chenh lech")
for i in range(0, len(y_Test)):
    print(y_Test.values[i], "\t", y_pred[i],"\t", y_Test.values[i]-y_pred[i])
# Out:
# Thuc te           Du doan                Chenh lech
# 2006 	 1878.3756363768694 	 127.62436362313065
# 1511 	 1513.0530147695085 	 -2.053014769508536
# 1777 	 1485.1870229551737 	 291.8129770448263
# 2685 	 2828.2816111799334 	 -143.2816111799334
# 833 	 872.5980432791662 	 -39.59804327916618
# 1676 	 1823.57733567587 	 -147.57733567587002
# 2276 	 2355.9349001152887 	 -79.93490011528866
# 2137 	 2463.9733846413205 	 -326.97338464132054
# 3658 	 3320.6263367727606 	 337.3736632272394
# 1396 	 1519.0736963107997 	 -123.07369631079973
# 2445 	 2327.902994521326 	 117.09700547867396
# 1302 	 1354.761065724476 	 -52.76106572447611
# 1612 	 1808.8279478835684 	 -196.8279478835684
# 1646 	 1707.5315147701751 	 -61.531514770175136
# 1396 	 1519.5760873331262 	 -123.57608733312622
# 2258 	 2300.060394609122 	 -42.060394609121886
# 1984 	 1965.2429607325703 	 18.757039267429718
# 2343 	 2362.417217479503 	 -19.41721747950305
# 2438 	 2810.831782362642 	 -372.8317823626421
# 1741 	 1724.7607901022586 	 16.239209897741375
# 1676 	 1824.0410812349405 	 -148.04108123494052
# 2491 	 2755.897387209731 	 -264.8973872097308
# 2466 	 2742.864815780351 	 -276.8648157803509
# 1989 	 2095.474222693787 	 -106.47422269378694
# 2137 	 2464.012030104576 	 -327.01203010457584
# 2054 	 2807.0454955706537 	 -753.0454955706537
# 2001 	 1981.3918489485482 	 19.60815105145184
# 1421 	 1235.4257670223778 	 185.57423297762216
# 2508 	 2406.8185990501097 	 101.1814009498903
# 2258 	 2300.4082037784246 	 -42.40820377842465
# 1238 	 1382.1785094827035 	 -144.17850948270348
# 791 	 808.5875354743091 	 -17.587535474309107
# 1916 	 1945.85050190405 	 -29.850501904049906
# 3551 	 3855.4762966091816 	 -304.47629660918165
# 2824 	 2859.827971347446 	 -35.82797134744578
# 3287 	 3312.2478428689674 	 -25.247842868967382
# 2880 	 3027.5305790672 	 -147.53057906720005
# 2276 	 2355.664381872498 	 -79.66438187249787
# 1749 	 1360.1918448318002 	 388.80815516819985
# 1302 	 1354.0268019226148 	 -52.02680192261482
# 3316 	 2869.932018818322 	 446.0679811816781
# 2124 	 2332.2696099413242 	 -208.26960994132423
# 614 	 667.8974092824969 	 -53.89740928249694
# 1734 	 1564.9254308673992 	 169.0745691326008
# 1522 	 1489.8007246384723 	 32.199275361527725
# 2859 	 3062.723812055283 	 -203.7238120552829
# 1921 	 1793.9824312849819 	 127.01756871501811
# 3116 	 3321.241918958436 	 -205.24191895843614
# 2880 	 3031.7429345620903 	 -151.74293456209034

# %%
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error
y_mean = np.mean(y_Test)
# Tính NSE
nse = 1 - (np.sum((y_Test - y_pred) ** 2) / np.sum((y_Test - y_mean) ** 2))

#Tinh R2
r2 = r2_score(y_Test, y_pred)

# Tính MAE
mae = mean_absolute_error(y_Test, y_pred)

# Tính RMSE
rmse = np.sqrt(mean_squared_error(y_Test, y_pred))

# In giá trị 
print("NSE:", nse)
print("R2: ", r2)
print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# NSE: 0.9044778659976963
# R2:  0.9044778659976963
# MAE: 156.89679450882846
# RMSE: 211.93353419399216
