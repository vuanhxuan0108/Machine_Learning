# %%
import matplotlib.pyplot as plt

# %%
models = ['LinearRegression', 'Neural Network', 'Ridge', 'Stacking']
NSE = [0.9143055994489925, 0.9356818958909814, 0.8900443813580798, 0.9259315593774854]
R2 = [0.9143055994489925, 0.9356818958909814, 0.8900443813580798, 0.9259315593774854]

# %%
plt.figure(figsize=(10, 6))
plt.plot(models, NSE, marker='o', label='NSE')
plt.plot(models, R2, marker='o', label='R2')

# %%
models = ['LinearRegression', 'Neural Network', 'Ridge', 'Stacking']
MAE = [220.22560145360535, 151.30476664208626, 243.44457241259792, 197.59753041820073]
RMSE = [ 272.95830996540644, 219.6061209198257, 309.19240056544993, 253.7679075423948]
plt.figure(figsize=(10, 6))
plt.plot(models, MAE, marker='o', label='MAE')
plt.plot(models, RMSE, marker='o', label='RMSE')
